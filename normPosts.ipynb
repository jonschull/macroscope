# %%
## PosterPoster
### based on forumThreads.json created by parseFromWikiFactory.ipynb, we present posts from G+ and WikiFactory.

# %%
from pathlib import Path
p=Path('forumThreads.json')
import json
t = p.read_text()
threads=json.loads(t)

# %%
postCounter=0
for thread in threads:
    postCounter+=1
    for comment in thread['comments']:
        postCounter+=1
print(f'{postCounter} posts in {len(threads)} threads')
# Out:
# 76238 posts in 13542 threads

# %% [markdown]
# ## time utils: timestamp(), datetime(), niceDateStr()
# Timestamps in the data come as strings in two forms (with "T" and without), and have ugly +00:00 at the end.
# Since sorting on string dates stumbles on '0', we have these utilities with 1 second resolution.

# %%
import arrow
from pandas import DataFrame

def timeInt(s='2015-11-17T20:43:01+00:00'):
    """timestamp is seconds since 1/1/1970
    """
    if 'T' in s:
        return arrow.get(s[:19], 'YYYY-MM-DDTHH:mm:ss').timestamp
    else:
        return arrow.get(s[:19], 'YYYY-MM-DD HH:mm:ss').timestamp
        
def timeInt_to_isoformat(timeInt):
    return arrow.Arrow.fromtimestamp(timeInt).isoformat()

# %% [markdown]
# ## normalize threads, sort by timeInt.  Takes several minutes

# %%
from bs4 import BeautifulSoup as soup
from pandas import DataFrame

import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')

from pprint import pprint

normThreads = []
for t in threads:
    t['timeInt']  = timeInt(  t['date_created'])  #DON'T CALL IT t['timestamp'] or it will get converted into a pandas timestamp! 
    t['body'] = soup(t['body']).text

    if 'comments' not in t:  #there are two 
        t['comments'] = [] 
    
    for i, comment in enumerate(t['comments']):
        t['comments'][i]['timeInt']   = timeInt(comment['date_created'])
        t['comments'][i]['body_html'] = comment['body']
        t['comments'][i]['body'] = soup(comment['body']).text
    normThreads.append(t)

# %%
from pandas import DataFrame
df = DataFrame(normThreads)
df = df.sort_values('timeInt')
df
# Out:
#                                                   author  \
# 6785   {'username': 'jonschull', 'avatar': 'https://w...
# 3363   {'username': 'jonschull', 'avatar': 'https://w...
# 6784   {'username': 'jonschull', 'avatar': 'https://w...
# 6783   {'username': 'matanpresberg', 'avatar': 'https...
# 13511  {'username': 'robohandsa', 'avatar': 'https://...
# 3362   {'username': 'jonschull', 'avatar': 'https://w...
# 6782   {'username': 'jaredmistretta', 'avatar': 'http...
# 10204  {'username': 'jonschull', 'avatar': 'https://w...
# 10203  {'username': 'jonschull', 'avatar': 'https://w...
# 13510  {'username': 'jonschull', 'avatar': 'https://w...
# 10202  {'username': 'jonschull', 'avatar': 'https://w...
# 10788  {'username': 'jonschull', 'avatar': 'https://w...
# 598    {'username': 'jonschull', 'avatar': 'https://w...
# 6781   {'username': 'jonschull', 'avatar': 'https://w...
# 6780   {'username': 'jonschull', 'avatar': 'https://w...
# 6779   {'username': 'markettepierce', 'avatar': 'http...
# 597    {'username': 'paolomirabelli', 'avatar': 'http...
# 3702   {'username': 'jonschull', 'avatar': 'https://w...
# 6778   {'username': 'kittyjuul', 'avatar': 'https://w...
# 10201  {'username': 'jonschull', 'avatar': 'https://w...
# 13509  {'username': 'jonschull', 'avatar': 'https://w...
# 3701   {'username': 'jonschull', 'avatar': 'https://w...
# 3361   {'username': 'albertmanero', 'avatar': 'https:...
# 13508  {'username': 'lyndapoole', 'avatar': 'https://...
# 6777   {'username': 'kittyjuul', 'avatar': 'https://w...
# 13507          {'username': 'gernreich', 'avatar': None}
# 13506  {'username': 'kittyjuul', 'avatar': 'https://w...
# 10787  {'username': 'albertmanero', 'avatar': 'https:...
# 10540  {'username': 'jonschull', 'avatar': 'https://w...
# 13505  {'username': 'jonschull', 'avatar': 'https://w...
# ...                                                  ...
# 4124      {'username': 'shawnmathiesen', 'avatar': None}
# 7516   {'username': 'ntallett', 'avatar': 'https://wi...
# 7517                {'username': 'jeff', 'avatar': None}
# 10892         {'username': 'layetall12', 'avatar': None}
# 7518            {'username': 'julexmac', 'avatar': None}
# 731    {'username': 'kreeser1', 'avatar': 'https://wi...
# 4125   {'username': 'yoav', 'avatar': 'https://wikifa...
# 4126          {'username': 'virajbagga', 'avatar': None}
# 4127   {'username': 'chriscarless', 'avatar': 'https:...
# 10893  {'username': 'valperezsteam', 'avatar': 'https...
# 4130   {'username': 'zico', 'avatar': 'https://wikifa...
# 10895  {'username': 'jeremy', 'avatar': 'https://wiki...
# 7520   {'username': '7awesomelives', 'avatar': 'https...
# 732         {'username': 'jgsarmientoc', 'avatar': None}
# 4131   {'username': 'yoav', 'avatar': 'https://wikifa...
# 733    {'username': 'nate-munro', 'avatar': 'https://...
# 4133          {'username': 'jalexander', 'avatar': None}
# 4134         {'username': 'campolglase', 'avatar': None}
# 10897  {'username': 'danpreecedpm', 'avatar': 'https:...
# 7521          {'username': 'archimedez', 'avatar': None}
# 4135   {'username': 'clintmaltais', 'avatar': 'https:...
# 4136   {'username': 'tom', 'avatar': 'https://wikifac...
# 10899  {'username': 'chris-versus3d', 'avatar': 'http...
# 7524   {'username': 'futtemut', 'avatar': 'https://wi...
# 0      {'username': 'yoav', 'avatar': 'https://wikifa...
# 1      {'username': 'yoav', 'avatar': 'https://wikifa...
# 3409       {'username': 'conradcarlson', 'avatar': None}
# 24     {'username': 'yoav', 'avatar': 'https://wikifa...
# 10261  {'username': 'pollockprosthetic', 'avatar': None}
# 10271  {'username': 'hardik', 'avatar': 'https://wiki...
#
#                                                     body  \
# 6785   Welcome to the companion site to this map[http...
# 3363   co-moderators wanted for each of the sub-topic...
# 6784   Poster explaining the vision for the e-nable n...
# 6783               hi, my name is Matan, I work with Jon
# 13511                   Robohand is on board! Thanks Jon
# 3362   Welcome!  1)  Join Community 2)  Create or rev...
# 6782   Hello! I'm Jared Mistretta and I work with Jon...
# 10204  This would be a good place for people to discu...
# 10203  I have the impression that there are two desig...
# 13510  Ultimately its about health, wellness, social ...
# 10202  What are the legal issues?  For example, liabi...
# 10788  Google+ communities are relatively new and I s...
# 598    Our ranks include technologists,  protheticist...
# 6781          Case studies and testimonials can go here.
# 6780   I'll go first.  (I hope you'll all reciprocate...
# 6779   I'll follow Jon's lead...I'm Markette Pierce. ...
# 597    Hi,I'm Paolo Mirabelli Ceo of Graphid3a TecnoA...
# 3702   New Socially Responsible Learning presentation...
# 6778   Hi Everyone! My name is Kitty Juul, and I live...
# 10201  Let's start talking about Expenses, Fund-raisi...
# 13509  Use this Topic to share Cool (e.g., emerging t...
# 3701   *SciTech **#ScienceSunday **](https://plus.goo...
# 3361   My name is Albert Manero, a graduate student a...
# 13508  Hello!  My name is Lynda Poole, and I am an Oc...
# 6777   I have created a sample Release and Waiver of ...
# 13507  ![](https://wikifactory.com/files/RmlsZToxMzE5...
# 13506  Here is the link to version 2 of the liability...
# 10787  Completed first test hand from the University ...
# 10540  Somehow I'd missed this.  It's got some good i...
# 13505  This beautiful and fascinating video suggests ...
# ...                                                  ...
# 4124   I will be printing my first hand and was wonde...
# 7516   Hello! I'm a volunteer working to provide e-NA...
# 7517   Hi Team. I am working on printing the Phoenix ...
# 10892  hello i am laye tall i live in senegal i am in...
# 7518   Hi - I just joined and am currently printing m...
# 731    **Portable e-NABLE Lab Project Proposal**I hav...
# 4125   https://www.eurekalert.org/pub_releases/2019-0...
# 4126   I have used a Printer Bot to build a hand. But...
# 4127   Hi allI have volunteered to help with case \#0...
# 10893  I am a K-6 STEAM teacher and working to start ...
# 4130   Good Morning Guys​I am a development consultan...
# 10895  We are updating our channel on YouTube and wil...
# 7520   Hello there. My name is Denys, I am a 3D Print...
# 732    Hola, mi nombre es José Sarmiento, tengo 34 añ...
# 4131   https://physicsworld.com/a/prosthetic-hand-con...
# 733    I wanted to say a big thank you to the e-NABLE...
# 4133   Currently my location is very rural and I don'...
# 4134   Hi everyone! My name is Cam and I am a student...
# 10897  hi﻿,  I'm totally new to enable.  If you guys ...
# 7521   I currently hail from just south of Baltimore,...
# 4135   Hello,I’m a teacher looking into printing and ...
# 4136   Hello e-Nable, I'm a neighbor over in the 3D p...
# 10899  Glad to be here! I currently own 18 printers a...
# 7524   ![image](https://wikifactory.com/files/RmlsZTo...
# 0      https://mashable.com/video/star-wars-inspired-...
# 1      https://www.medgadget.com/2019/08/implanted-el...
# 3409   Hi all - I am new to both 3d printing and pros...
# 24     https://techcrunch.com/2019/08/22/silicone-3d-...
# 10261  We are a new club making the prosthetics in me...
# 10271  Hello Everyone!I and my friend @anupniroula ha...
#
#                                                body_html  \
# 6785   <p>Welcome to the companion site to this map<a...
# 3363   <p>co-moderators wanted for each of the sub-to...
# 6784   <p>Poster explaining the vision for the e-nabl...
# 6783        <p>hi, my name is Matan, I work with Jon</p>
# 13511            <p>Robohand is on board! Thanks Jon</p>
# 3362   <p>Welcome!  </p><p>1)  Join Community 2)  Cre...
# 6782   <p>Hello! I'm Jared Mistretta and I work with ...
# 10204  <p>This would be a good place for people to di...
# 10203  <p>I have the impression that there are two de...
# 13510  <p>Ultimately its about health, wellness, soci...
# 10202  <p>What are the legal issues?  For example, li...
# 10788  <p>Google+ communities are relatively new and ...
# 598    <p>Our ranks include technologists,  prothetic...
# 6781   <p>Case studies and testimonials can go here.</p>
# 6780   <p>I'll go first.  (I hope you'll all reciproc...
# 6779   <p>I'll follow Jon's lead...</p><p>I'm Markett...
# 597    <p>Hi,I'm Paolo Mirabelli Ceo of Graphid3a Tec...
# 3702   <p>New Socially Responsible Learning presentat...
# 6778   <p>Hi Everyone! My name is Kitty Juul, and I l...
# 10201  <p>Let's start talking about Expenses, Fund-ra...
# 13509  <p>Use this Topic to share Cool (e.g., emergin...
# 3701   <p><em>SciTech </em><em>#ScienceSunday &lt;<a ...
# 3361   <p>My name is Albert Manero, a graduate studen...
# 13508  <p>Hello!  My name is Lynda Poole, and I am an...
# 6777   <p>I have created a sample Release and Waiver ...
# 13507  <p><img alt="" src="https://wikifactory.com/fi...
# 13506  <p>Here is the link to version 2 of the liabil...
# 10787  <p>Completed first test hand from the Universi...
# 10540  <p>Somehow I'd missed this.  It's got some goo...
# 13505  <p>This beautiful and fascinating video sugges...
# ...                                                  ...
# 4124   <p>I will be printing my first hand and was wo...
# 7516   <p>Hello! I'm a volunteer working to provide e...
# 7517   <p>Hi Team. I am working on printing the Phoen...
# 10892  <p>hello i am laye tall i live in senegal i am...
# 7518   <p>Hi - I just joined and am currently printin...
# 731    <pre><code>                                   ...
# 4125   <p>https://www.eurekalert.org/pub_releases/201...
# 4126   <p>I have used a Printer Bot to build a hand. ...
# 4127   <p>Hi all</p><p>I have volunteered to help wit...
# 10893  <p>I am a K-6 STEAM teacher and working to sta...
# 4130   <p>Good Morning Guys</p><p>​</p><p>I am a deve...
# 10895  <p>We are updating our channel on YouTube and ...
# 7520   <p>Hello there. My name is Denys, I am a 3D Pr...
# 732    <p>Hola, mi nombre es José Sarmiento, tengo 34...
# 4131   <p>https://physicsworld.com/a/prosthetic-hand-...
# 733    <p>I wanted to say a big thank you to the e-NA...
# 4133   <p>Currently my location is very rural and I d...
# 4134   <p>Hi everyone! My name is Cam and I am a stud...
# 10897  <p>hi﻿,  I'm totally new to enable.  If you gu...
# 7521   <p>I currently hail from just south of Baltimo...
# 4135   <p>Hello,</p><p>I’m a teacher looking into pri...
# 4136   <p>Hello e-Nable, I'm a neighbor over in the 3...
# 10899  <p>Glad to be here! I currently own 18 printer...
# 7524   <p><img alt="image" src="https://wikifactory.c...
# 0      <p>https://mashable.com/video/star-wars-inspir...
# 1      <p>https://www.medgadget.com/2019/08/implanted...
# 3409   <p>Hi all - I am new to both 3d printing and p...
# 24     <p>https://techcrunch.com/2019/08/22/silicone-...
# 10261  <p>We are a new club making the prosthetics in...
# 10271  <p>Hello Everyone!</p><p>I and my friend @anup...
#
#                              category  \
# 6785             Legal, Documents, $$
# 3363            Announcements & Admin
# 6784             Legal, Documents, $$
# 6783                    Introductions
# 13511                   Introductions
# 3362
# 6782                    Introductions
# 10204              General Discussion
# 10203          Research & Development
# 13510              General Discussion
# 10202            Legal, Documents, $$
# 10788           Announcements & Admin
# 598             Announcements & Admin
# 6781   Case Studies, Stories & Prints
# 6780                    Introductions
# 6779                    Introductions
# 597                General Discussion
# 3702            Announcements & Admin
# 6778               General Discussion
# 10201              General Discussion
# 13509         Cool and Relevant Stuff
# 3701          Cool and Relevant Stuff
# 3361                    Introductions
# 13508                   Introductions
# 6777             Legal, Documents, $$
# 13507          Research & Development
# 13506            Legal, Documents, $$
# 10787          Research & Development
# 10540          Research & Development
# 13505         Cool and Relevant Stuff
# ...                               ...
# 4124               Device Information
# 7516                    Introductions
# 7517               General Discussion
# 10892              General Discussion
# 7518                    Introductions
# 731             Announcements & Admin
# 4125          Cool and Relevant Stuff
# 4126               Device Information
# 4127               General Discussion
# 10893                   Introductions
# 4130                    Introductions
# 10895           Announcements & Admin
# 7520                    Introductions
# 732                     Introductions
# 4131          Cool and Relevant Stuff
# 733                General Discussion
# 4133                    Introductions
# 4134                    Introductions
# 10897              Device Information
# 7521                    Introductions
# 4135               General Discussion
# 4136               General Discussion
# 10899                   Introductions
# 7524               General Discussion
# 0             Cool and Relevant Stuff
# 1             Cool and Relevant Stuff
# 3409                    Introductions
# 24            Cool and Relevant Stuff
# 10261                   Introductions
# 10271                   Introductions
#
#                                                 comments  \
# 6785   [{'date_created': '2013-07-10T20:36:01+00:00',...
# 3363                                                  []
# 6784   [{'date_created': '2013-07-12T17:50:15+00:00',...
# 6783                                                  []
# 13511                                                 []
# 3362   [{'date_created': '2013-08-18T17:17:28+00:00',...
# 6782   [{'date_created': '2013-07-13T12:05:59+00:00',...
# 10204                                                 []
# 10203  [{'date_created': '2013-07-12T23:10:54+00:00',...
# 13510  [{'date_created': '2013-07-13T00:01:31+00:00',...
# 10202  [{'date_created': '2013-07-13T18:27:11+00:00',...
# 10788  [{'date_created': '2013-10-09T19:16:57+00:00',...
# 598    [{'date_created': '2013-07-13T12:53:59+00:00',...
# 6781                                                  []
# 6780                                                  []
# 6779   [{'date_created': '2014-04-27T03:59:30+00:00',...
# 597    [{'date_created': '2013-07-16T00:42:03+00:00',...
# 3702   [{'date_created': '2013-07-21T01:22:33+00:00',...
# 6778   [{'date_created': '2014-05-26T05:10:07+00:00',...
# 10201  [{'date_created': '2013-07-21T15:18:31+00:00',...
# 13509                                                 []
# 3701                                                  []
# 3361   [{'date_created': '2013-07-22T11:11:01+00:00',...
# 13508  [{'date_created': '2014-05-26T04:02:20+00:00',...
# 6777   [{'date_created': '2013-07-26T19:28:16+00:00',...
# 13507  [{'date_created': '2013-07-28T00:31:32+00:00',...
# 13506  [{'date_created': '2013-08-08T12:14:08+00:00',...
# 10787  [{'date_created': '2013-07-28T21:26:19+00:00',...
# 10540                                                 []
# 13505  [{'date_created': '2013-07-28T20:49:06+00:00',...
# ...                                                  ...
# 4124   [{'date_created': '2019-06-19T18:42:09.199089+...
# 7516   [{'date_created': '2019-06-19T21:58:02.671282+...
# 7517   [{'date_created': '2019-06-22T11:12:01.563590+...
# 10892  [{'date_created': '2019-06-22T11:02:36.850028+...
# 7518   [{'date_created': '2019-06-25T20:27:46.336242+...
# 731    [{'date_created': '2019-06-28T01:58:16.046306+...
# 4125                                                  []
# 4126                                                  []
# 4127   [{'date_created': '2019-07-11T18:21:09.682814+...
# 10893  [{'date_created': '2019-07-13T18:44:06.092420+...
# 4130   [{'date_created': '2019-07-16T09:16:40.275966+...
# 10895  [{'date_created': '2019-07-17T16:43:00.428673+...
# 7520   [{'date_created': '2019-07-18T18:38:58.265714+...
# 732    [{'date_created': '2019-08-13T20:04:54.203654+...
# 4131                                                  []
# 733    [{'date_created': '2019-07-22T09:35:32.436297+...
# 4133   [{'date_created': '2019-07-23T23:11:45.588852+...
# 4134   [{'date_created': '2019-07-25T01:09:50.436142+...
# 10897  [{'date_created': '2019-07-30T23:12:47.422474+...
# 7521   [{'date_created': '2019-08-04T00:17:32.016334+...
# 4135   [{'date_created': '2019-08-05T18:31:25.331500+...
# 4136                                                  []
# 10899                                                 []
# 7524   [{'date_created': '2019-08-10T18:07:06.686490+...
# 0                                                     []
# 1                                                     []
# 3409                                                  []
# 24                                                    []
# 10261                                                 []
# 10271                                                 []
#
#                            date_created  members_only     timeInt  \
# 6785          2013-07-10T20:01:06+00:00          True  1373486466
# 3363          2013-07-11T04:35:45+00:00          True  1373517345
# 6784          2013-07-11T06:40:51+00:00          True  1373524851
# 6783          2013-07-12T16:25:49+00:00          True  1373646349
# 13511         2013-07-12T17:47:03+00:00          True  1373651223
# 3362          2013-07-12T19:28:56+00:00          True  1373657336
# 6782          2013-07-12T22:04:27+00:00          True  1373666667
# 10204         2013-07-12T22:47:08+00:00          True  1373669228
# 10203         2013-07-12T22:49:04+00:00          True  1373669344
# 13510         2013-07-12T22:51:12+00:00          True  1373669472
# 10202         2013-07-12T22:53:47+00:00          True  1373669627
# 10788         2013-07-12T22:54:42+00:00          True  1373669682
# 598           2013-07-12T22:56:59+00:00          True  1373669819
# 6781          2013-07-12T22:58:30+00:00          True  1373669910
# 6780          2013-07-13T20:48:24+00:00          True  1373748504
# 6779          2013-07-13T21:08:48+00:00          True  1373749728
# 597           2013-07-15T18:33:42+00:00          True  1373913222
# 3702          2013-07-16T12:46:43+00:00          True  1373978803
# 6778          2013-07-20T23:07:11+00:00          True  1374361631
# 10201         2013-07-21T14:45:09+00:00          True  1374417909
# 13509         2013-07-21T14:50:09+00:00          True  1374418209
# 3701          2013-07-21T14:50:23+00:00          True  1374418223
# 3361          2013-07-22T02:25:57+00:00          True  1374459957
# 13508         2013-07-23T03:48:17+00:00          True  1374551297
# 6777          2013-07-26T19:25:13+00:00          True  1374866713
# 13507         2013-07-28T00:30:49+00:00          True  1374971449
# 13506         2013-07-28T15:38:20+00:00          True  1375025900
# 10787         2013-07-28T20:21:07+00:00          True  1375042867
# 10540         2013-07-28T20:33:09+00:00          True  1375043589
# 13505         2013-07-28T20:39:49+00:00          True  1375043989
# ...                                 ...           ...         ...
# 4124   2019-06-19T02:01:23.392115+00:00         False  1560909683
# 7516   2019-06-19T03:14:04.741033+00:00         False  1560914044
# 7517   2019-06-20T10:00:59.955519+00:00         False  1561024859
# 10892  2019-06-21T09:36:03.240038+00:00         False  1561109763
# 7518   2019-06-24T18:17:41.233175+00:00         False  1561400261
# 731    2019-06-26T19:41:13.303725+00:00         False  1561578073
# 4125   2019-06-28T05:32:21.369410+00:00         False  1561699941
# 4126   2019-07-08T16:19:47.242502+00:00         False  1562602787
# 4127   2019-07-11T14:31:35.947586+00:00         False  1562855495
# 10893  2019-07-12T18:03:14.808302+00:00         False  1562954594
# 4130   2019-07-15T06:37:39.508870+00:00         False  1563172659
# 10895  2019-07-16T00:46:24.337287+00:00         False  1563237984
# 7520   2019-07-17T19:27:50.880668+00:00         False  1563391670
# 732    2019-07-18T03:06:48.820520+00:00         False  1563419208
# 4131   2019-07-18T13:16:53.989530+00:00         False  1563455813
# 733    2019-07-21T06:12:14.910795+00:00         False  1563689534
# 4133   2019-07-23T23:05:06.170367+00:00         False  1563923106
# 4134   2019-07-25T01:01:57.253713+00:00         False  1564016517
# 10897  2019-07-30T13:21:22.012043+00:00         False  1564492882
# 7521   2019-08-02T23:00:37.457713+00:00         False  1564786837
# 4135   2019-08-04T19:36:32.257741+00:00         False  1564947392
# 4136   2019-08-06T00:20:09.143082+00:00         False  1565050809
# 10899  2019-08-08T12:15:44.245897+00:00         False  1565266544
# 7524   2019-08-10T06:27:37.004739+00:00         False  1565418457
# 0      2019-08-13T14:04:24.626243+00:00         False  1565705064
# 1      2019-08-13T15:30:48.685328+00:00         False  1565710248
# 3409   2019-08-16T23:02:51.402365+00:00         False  1565996571
# 24     2019-08-24T05:37:35.575880+00:00         False  1566625055
# 10261  2019-08-24T15:33:27.284561+00:00         False  1566660807
# 10271  2019-08-26T13:05:40.992713+00:00         False  1566824740
#
#                                                    title
# 6785        Welcome to the companion site to this map...
# 3363   co-moderators wanted for each of the sub-topic...
# 6784   Poster explaining the vision for the e-nable n...
# 6783               hi, my name is Matan, I work with Jon
# 13511                   Robohand is on board! Thanks Jon
# 3362                                       Welcome!  ...
# 6782   Hello! I'm Jared Mistretta and I work with Jon...
# 10204  This would be a good place for people to discu...
# 10203  I have the impression that there are two desig...
# 13510  Ultimately its about health, wellness, social ...
# 10202  What are the legal issues?  For example, liabi...
# 10788  Google+ communities are relatively new and I s...
# 598    Our ranks include technologists,  protheticist...
# 6781          Case studies and testimonials can go here.
# 6780   I'll go first.  (I hope you'll all reciprocate...
# 6779                        I'll follow Jon's lead......
# 597                                               Hi,...
# 3702   New Socially Responsible Learning presentation...
# 6778   Hi Everyone! My name is Kitty Juul, and I live...
# 10201  Let's start talking about Expenses, Fund-raisi...
# 13509  Use this Topic to share Cool (e.g., emerging t...
# 3701                       *SciTech **#ScienceSunday ...
# 3361   My name is Albert Manero, a graduate student a...
# 13508  Hello!  My name is Lynda Poole, and I am an Oc...
# 6777   I have created a sample Release and Waiver of ...
# 13507                                        Photo album
# 13506  Here is the link to version 2 of the liability...
# 10787  Completed first test hand from the University ...
# 10540  Somehow I'd missed this.  It's got some good i...
# 13505  This beautiful and fascinating video suggests ...
# ...                                                  ...
# 4124           Recommended infill % for Unlimbited hand?
# 7516      Current designs for above the elbow prostheses
# 7517       Looking for Kits Suppliers in Southern Africa
# 10892                                            bonjour
# 7518                                     London calling!
# 731    NEW e-NABLio Proposal - Portable e-NABLE Lab (...
# 4125   3D printed prosthetic hand can guess how you p...
# 4126        TRONXY XY-3 3D Printer Pro for printing hand
# 4127                                      Help with case
# 10893   STEAM Teacher Excited to Join e-Nable Community!
# 4130   South Africa- Development Consultant based in ...
# 10895                    Updated e-NABLE YouTube Channel
# 7520                            Hello from GMU, Virginia
# 732                       Venezuela - Ingeniero Mecánico
# 4131   Prosthetic hand controls finger motion with hi...
# 733                                  12 new NIOP devices
# 4133                      Hello! Looking to help design.
# 4134                                         Hello all!
# 10897                                    Printer option?
# 7521                                        Hello All :)
# 4135                            Enquiry - Western Canada
# 4136   Ceramic Printing Custom Objects to Increase In...
# 10899      Hi Everyone! - I'm looking for some direction
# 7524                        which hand for this girl :-)
# 0                           DEKA Luke arm becomes touchy
# 1      Implanted Electrodes Improve Powered Prostheti...
# 3409              New member in the Bay Area, California
# 24                             A new Silicone 3D Printer
# 10261                                New Club in Vermont
# 10271                 New Members from Sydney, Australia
#
# [13542 rows x 9 columns]

# %% [markdown]
# ## create normPosts, normPosts.csv is our candidate for the Graph

# %%
normPosts = []
#Create IDs

for ti,thread in enumerate(df.to_dict('records')):

    thread['ID'] = ti        #then all the comments
    normPosts.append(thread) #first the thread
    
    #create IDs for each comment based on the ID of the ThreadHead
    for ci, comment in enumerate(thread['comments']):
        num= ci + 1
        comment['ID'] = ti + (num/1000) #e.g., 3.025 for the 
        normPosts.append(comment)

# %%
#give them all isoformat strings

for pi, post in enumerate(normPosts):
    normPosts[pi]['isoformat'] = timeInt_to_isoformat(post['timeInt'])

# %%
df = DataFrame(normPosts)

# %%
df.columns, len(df)
# Out:
# (Index(['ID', 'author', 'body', 'body_html', 'category', 'comments',
#         'date_created', 'isoformat', 'members_only', 'timeInt', 'title'],
#        dtype='object'), 76238)

# %%
df.to_json('normPosts.json') #save
len(df)
# Out:
# 76238
